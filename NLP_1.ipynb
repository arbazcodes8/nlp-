# %% [markdown]
# <a href="https://colab.research.google.com/github/arbazcodes8/nlp-/blob/main/NLP_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install nltk

# %%
import nltk
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
from nltk.tokenize import word_tokenize,sent_tokenize

# %%
input = "hi i am Arbaz. How are you"
output1 = word_tokenize(input)
print(output1)

output2 = sent_tokenize(input)
print(output2)
# Out:
# ['hi', 'i', 'am', 'Arbaz', '.', 'How', 'are', 'you']
# ['hi i am Arbaz.', 'How are you']
